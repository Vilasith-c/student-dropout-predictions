# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\18SS0\OneDrive\Desktop\Main\Papers\Research\student-dropout-predictions\data\raw\data.csv", sep=";")
print(df.shape)
df.info()
print(df.columns)
df["Target"].value_counts(normalize=True)
# Out:
# (4424, 37)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 37 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4424 non-null   int64
#  1   Application mode                                4424 non-null   int64
#  2   Application order                               4424 non-null   int64
#  3   Course                                          4424 non-null   int64
#  4   Daytime/evening attendance	                     4424 non-null   int64
#  5   Previous qualification                          4424 non-null   int64
#  6   Previous qualification (grade)                  4424 non-null   float64
#  7   Nacionality                                     4424 non-null   int64
#  8   Mother's qualification                          4424 non-null   int64
# ...

# %% [markdown]
# Dataset: 4,424 students, 37 columns (36 features + Target).​
#
# Class distribution: Graduate ≈ 50%, Dropout ≈ 32%, Enrolled ≈ 18% (mild imbalance).​
#
# Baseline Logistic Regression (no scaling, default solver) on 80/20 split:
#
# Accuracy ≈ 0.74
#
# Macro F1 ≈ 0.63, Weighted F1 ≈ 0.71
#
# Good performance on Graduate, weaker recall for Enrolled (only 0.24).

# %%
# Dataset overview

- Rows: 4,424 students  
- Columns: 37 (36 features + Target)

## Class distribution
- Graduate: ≈ 50%  
- Dropout: ≈ 32%  
- Enrolled: ≈ 18% (mild imbalance)

## Baseline model (Logistic Regression — default solver, no scaling, 80/20 split)
- Accuracy: ≈ 0.74  
- Macro F1: ≈ 0.63  
- Weighted F1: ≈ 0.71  
- Notes: Good performance on "Graduate"; weaker recall for "Enrolled" (~0.24).
# Out:
#   Cell In[3], line 7
#     - Graduate: ≈ 50%
#                 ^
# SyntaxError: invalid character '≈' (U+2248)
